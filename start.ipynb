# %% [markdown]
# <h2>Data Structures</h2>

# %% [markdown]
# <h3>String</h3>
# <p>String merupakan karakter yang berurutan. Ketika Anda membuat variabel bernilai string tentu diawali dengan single quote (‘’) atau double quote (“”). </p>

# %%
print("hello")
# Out:
# hello

# %%
# x = 'Dicoding'
x= [2,1]
print(type(x))
# Out:
# <class 'list'>

# %%
#Multiline 
multi_line = """Halo!
Kapan terakhir kali kita bertemu?
Kita bertemu hari Jum’at yang lalu."""

print(multi_line)
# Out:
# Halo!
# Kapan terakhir kali kita bertemu?
# Kita bertemu hari Jum’at yang lalu.

# %%
x = 'Dicoding'
print(x[0])
print(x[2:])
# Out:
# D
# coding

# %%
name = "Perseus Evans"
print(f"Hello, nama saya {name}")
print("Nama saya %s" % (name))
print("Nama saya {}".format(name))
print("Nama saya " +  name + " heh")
# Out:
# Hello, nama saya Perseus Evans
# Nama saya Perseus Evans
# Nama saya Perseus Evans
# Nama saya Perseus Evans heh

# %% [markdown]
# <h3>LIST</h3>
# <p> kumpulan data terurut (ordered sequence) dan salah satu tipe data yang sering digunakan pada Python. List dalam Python ini serupa, tetapi tak sama dengan array pada bahasa pemrograman lainnya. List Python tidak mengharuskan memiliki tipe data yang sama di dalamnya, sedangkan array sebaliknya. </p>

# %%
x = [1, 2.2, 'Dicoding']
print(type(x))
# Out:
# <class 'list'>

# %%
print(x[2])
# Out:
# Dicoding

# %% [markdown]
# List Python bersifat mutable yang artinya nilai di dalamnya dapat diubah

# %%
x[0] = 'Indonesia'
print(x)
# Out:
# ['Indonesia', 2.2, 'Dicoding']

# %%
x = ["laptop", "monitor", "mouse", "mousepad", "keyboard", "webcam", "microphone"]

print(x[0])
print(x[2])
print(x[-1])
print(x[-3])
# Out:
# laptop
# mouse
# microphone
# keyboard

# %% [markdown]
# <h2>Tuple</h3>
# Tuple adalah jenis dari list yang tidak dapat diubah elemennya. Umumnya, tuple digunakan untuk data yang bersifat sekali deklarasi dan dapat dieksekusi lebih cepat.

# %%
x = (1, "Dicoding", 1+3j)
print(type(x))
# Out:
# <class 'tuple'>

# %%
x = (5, 'program', 1+3j)
print(x[1])
print(x[0:1])
# Out:
# program
# (5,)

# %% [markdown]
# <h2>Set</h2>
#  kumpulan item bersifat unik, tanpa urutan (unordered collection), dan dapat diinisialisasikan dengan kurawal “{}” di mana setiap elemennya dipisahkan dengan koma.
#  Tidak sama seperti list, dalam set kita tidak bisa melakukan indeksing karena set tidak memiliki indeks. Hal ini merujuk pada definisi nya yang menyatakan bahwa set merupakan kumpulan item tanpa urutan.

# %%
x = {1,2,7,2,3,13,3}
print(x[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Workspace\Code\Python\Start-Python\start.ipynb Cell 18 line 2
#       <a href='vscode-notebook-cell:/c%3A/Workspace/Code/Python/Start-Python/start.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> x = {1,2,7,2,3,13,3}
# ----> <a href='vscode-notebook-cell:/c%3A/Workspace/Code/Python/Start-Python/start.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> print(x[0])
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# program mengembalikan output 'set' object is not subscriptable karena setiap nilai dalam set tidak memiliki indeks sehingga tidak bisa dilakukan indexing.

# %% [markdown]
# Selain tanpa urutan (unordered collection). Set juga bersifat unik, artinya, data yang Anda simpan pada set tidak akan ada duplikat

# %%
x = {1, 2, 7, 2, 3, 13, 3}
print(x)
print(type(x))
# Out:
# {1, 2, 3, 7, 13}
# <class 'set'>

# %% [markdown]
# Terakhir, <span><bold>set</bold></span> adalah himpunan dalam matematika. Ini maknanya Anda dapat melakukan operasi union (gabungan) dan intersection (irisan) pada set. Python menyediakan method “.union()” dan “.intersection()” untuk tipe data set.

# %%
set1 = {1, 2, 3, 4, 5}
set2 = {4, 5, 6, 7, 8}

union = set1.union(set2)
print("Union:", union)

intersection = set1.intersection(set2)
print("Intersection:", intersection)
# Out:
# Union: {1, 2, 3, 4, 5, 6, 7, 8}
# Intersection: {4, 5}

# %% [markdown]
# <h2>Dictionary</h2>
# Dictionary pada Python merupakan kumpulan pasangan key-value yang bersifat tidak berurutan. Dictionary dapat digunakan untuk menyimpan data kecil hingga besar. Pada Python, dictionary didefinisikan dengan kurawal dan tambahan definisi berikut.
#
# -- Setiap elemen pasangan key-value dipisahkan dengan koma (,). <br>
# -- Key dan value dipisahkan dengan titik dua (:). <br>
# -- Key dan value dapat berupa tipe variabel/objek apa pun.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = { 'name': 'Perseus Evans', 'age': 20, 'isMarried': False }

print(type(x))
# Out:
# <class 'dict'>

# %%
x = { 'name': 'Perseus Evans', 'age': 20, 'isMarried': False }

print(x[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Workspace\Code\Python\Start-Python\start.ipynb Cell 27 line 3
#       <a href='vscode-notebook-cell:/c%3A/Workspace/Code/Python/Start-Python/start.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> x = { 'name': 'Perseus Evans', 'age': 20, 'isMarried': False }
# ----> <a href='vscode-notebook-cell:/c%3A/Workspace/Code/Python/Start-Python/start.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a> print(x[0])
#
# KeyError: 0

# %%
x = { 'name': 'Perseus Evans', 'age': 20, 'isMarried': False }

print(x ['name'])
# Out:
# Perseus Evans

# %% [markdown]
# <h3>Menambah Data pada Dictionary</h3>

# %%
x = { 'name': 'Perseus Evans', 'age': 20, 'isMarried': False }
x ['Job'] = "Web Developer"
x['name'] = 'hikam'

print(x)
# Out:
# {'name': 'hikam', 'age': 20, 'isMarried': False, 'Job': 'Web Developer'}

# %% [markdown]
# <h3>Menghapus Data pada Dictionary</h3>

# %%
x = { 'name': 'Perseus Evans', 'age': 20, 'isMarried': False }


print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Workspace\Code\Python\Start-Python\start.ipynb Cell 32 line 4
#       <a href='vscode-notebook-cell:/c%3A/Workspace/Code/Python/Start-Python/start.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> x = { 'name': 'Perseus Evans', 'age': 20, 'isMarried': False }
#       <a href='vscode-notebook-cell:/c%3A/Workspace/Code/Python/Start-Python/start.ipynb#X43sZmlsZQ%3D%3D?line=1'>2</a> del x
# ----> <a href='vscode-notebook-cell:/c%3A/Workspace/Code/Python/Start-Python/start.ipynb#X43sZmlsZQ%3D%3D?line=3'>4</a> print(x)
#
# NameError: name 'x' is not defined

# %% [markdown]
# <h3>Mengubah Data pada Dictionary</h3>

# %%
x = { 'name': 'Perseus Evans', 'age': 20, 'isMarried': False }
x ['name'] = "Dicoding"

print(x)
# Out:
# {'name': 'Dicoding', 'age': 20, 'isMarried': False}

# %% [markdown]
# <h2>Konversi data</h3>

# %%
print(set([1,2,3]))
print(tuple({5,6,7}))
print(list('hello'))
# Out:
# {1, 2, 3}
# (5, 6, 7)
# ['h', 'e', 'l', 'l', 'o']

# %%
x = 12
x = str(x)
print(type(x))
# Out:
# <class 'int'>
